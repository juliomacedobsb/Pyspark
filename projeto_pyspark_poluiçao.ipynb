# %% [markdown]
# <a href="https://colab.research.google.com/github/juliomacedobsb/Pyspark/blob/main/projeto_pyspark_polui%C3%A7ao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pyspark
import matplotlib
import matplotlib
import pandas

print(matplotlib.__version__)
print(pyspark.__version__)
print(pandas.__version__)
# Out:
# 3.7.0
# 3.2.1
# 1.5.3

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("projeto").getOrCreate()
# Out:
# 23/05/05 09:50:22 WARN Utils: Your hostname, cliente-Inspiron-3583 resolves to a loopback address: 127.0.1.1; using 192.168.15.7 instead (on interface wlo1)
# 23/05/05 09:50:22 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/home/cliente/anaconda3/lib/python3.10/site-packages/pyspark/jars/spark-unsafe_2.12-3.2.1.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# ...

# %%
from pyspark.sql.types import *

schema = StructType([
    StructField("Classificação", StringType(), True),
    StructField("Cidade", StringType(), True),
    StructField("2022", IntegerType(), True),
    StructField("janeiro", DoubleType(), True),
    StructField("FEV", DoubleType(), True),
    StructField("MAR", DoubleType(), True),
    StructField("ABR", DoubleType(), True),
    StructField("MAIO", DoubleType(), True),
    StructField("JUNHO", DoubleType(), True),
    StructField("julho", DoubleType(), True),
    StructField("AGO", DoubleType(), True),
    StructField("setembro", DoubleType(), True),
    StructField("OUTUBRO", DoubleType(), True),
    StructField("NOV", DoubleType(), True),
    StructField("DEZ", DoubleType(), True),
    StructField("2021", DoubleType(), True),
    StructField("2020", DoubleType(), True),
    StructField("2019", DoubleType(), True),
    StructField("2018", DoubleType(), True)
])

# %%
df = spark.read.csv("/home/cliente/download/Air Pollution.csv", header=True, schema=schema)

# %%
df.show(20)
# Out:
# +-------------+--------------------+----+-------+-----+-----+-----+-----+-----+-----+-----+--------+-------+-----+-----+-----+-----+-----+-----+
# |Classificação|              Cidade|2022|janeiro|  FEV|  MAR|  ABR| MAIO|JUNHO|julho|  AGO|setembro|OUTUBRO|  NOV|  DEZ| 2021| 2020| 2019| 2018|
# +-------------+--------------------+----+-------+-----+-----+-----+-----+-----+-----+-----+--------+-------+-----+-----+-----+-----+-----+-----+
# |            1|PakistanLahore, P...|null|  133.0|102.5| 85.6| 69.3| 60.9| 52.1| 47.8| 46.2|    64.2|  123.2|190.5|192.9| 86.5| 79.2| 89.5|114.9|
# |            2|   ChinaHotan, China|null|   61.7| 91.6|132.7|106.2|120.5| 69.5|172.5| 75.0|    65.1|   75.0| 50.3|120.0|101.5|110.2|110.1|116.0|
# |            3| IndiaBhiwadi, India|null|  110.6| 98.0|116.2|149.5|123.8|102.8| 38.8| 36.5|    59.9|   85.4|111.4| 86.9|106.2| 95.5| 83.4|125.4|
# ...

# %%
df3 = df1.head(15)
# Out:
# 23/05/05 10:46:52 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: Rank, City, JAN, FEB, MAR
#  Schema: Classificação, Cidade, janeiro, FEV, MAR
# Expected: Classificação but found: Rank
# CSV file: file:///home/cliente/download/Air%20Pollution.csv

# %%
df1 = df.select("Classificação", "Cidade","janeiro", "FEV", "MAR",  )

# %%
df2 = df.select("Classificação", "Cidade", "OUTUBRO", "NOV", "DEZ")

# %%
df1.show(5)
# Out:
# +-------------+--------------------+-------+-----+-----+
# |Classificação|              Cidade|janeiro|  FEV|  MAR|
# +-------------+--------------------+-------+-----+-----+
# |            1|PakistanLahore, P...|  133.0|102.5| 85.6|
# |            2|   ChinaHotan, China|   61.7| 91.6|132.7|
# |            3| IndiaBhiwadi, India|  110.6| 98.0|116.2|
# |            4|IndiaDelhi (NCT),...|  141.0|100.9| 91.0|
# |            5|PakistanPeshawar,...|  110.2|103.5| 78.3|
# +-------------+--------------------+-------+-----+-----+
# only showing top 5 rows
# 23/05/05 10:47:45 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: Rank, City, JAN, FEB, MAR
#  Schema: Classificação, Cidade, janeiro, FEV, MAR
# Expected: Classificação but found: Rank
# CSV file: file:///home/cliente/download/Air%20Pollution.csv

# %%
df2.show(5)
# Out:
# +-------------+--------------------+-------+-----+-----+
# |Classificação|              Cidade|OUTUBRO|  NOV|  DEZ|
# +-------------+--------------------+-------+-----+-----+
# |            1|PakistanLahore, P...|  123.2|190.5|192.9|
# |            2|   ChinaHotan, China|   75.0| 50.3|120.0|
# |            3| IndiaBhiwadi, India|   85.4|111.4| 86.9|
# |            4|IndiaDelhi (NCT),...|   99.7|176.8|171.9|
# |            5|PakistanPeshawar,...|  100.0|132.0|212.1|
# +-------------+--------------------+-------+-----+-----+
# only showing top 5 rows
# 23/05/05 10:47:59 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: Rank, City, OCT, NOV, DEC
#  Schema: Classificação, Cidade, OUTUBRO, NOV, DEZ
# Expected: Classificação but found: Rank
# CSV file: file:///home/cliente/download/Air%20Pollution.csv

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df4 = df.select("Classificação", "Cidade", "OUTUBRO")

dff_pandas = df4.toPandas()
# Out:
# 23/05/03 09:16:16 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: Rank, City, OCT
#  Schema: Classificação, Cidade, OUTUBRO
# Expected: Classificação but found: Rank
# CSV file: file:///home/cliente/download/Air%20Pollution.csv

# %%
df_pandas = df1.toPandas()
# Out:
# 23/05/05 11:05:34 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: Rank, City, JAN, FEB, MAR
#  Schema: Classificação, Cidade, janeiro, FEV, MAR
# Expected: Classificação but found: Rank
# CSV file: file:///home/cliente/download/Air%20Pollution.csv

# %%
df_pandas2 = df2.toPandas()
# Out:
# 23/05/05 11:05:38 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: Rank, City, OCT, NOV, DEC
#  Schema: Classificação, Cidade, OUTUBRO, NOV, DEZ
# Expected: Classificação but found: Rank
# CSV file: file:///home/cliente/download/Air%20Pollution.csv

# %%
df_pandas3 = df_pandas.head(15).copy()

# %%
df_pandas4 = df_pandas2.head(15).copy()

# %% [markdown]
# df_pandas.plot(classif='Classificação', cidade='Cidade')

# %%
df_pandas2
# Out:
#      Classificação                      Cidade  OUTUBRO    NOV    DEZ
# 0                1    PakistanLahore, Pakistan    123.2  190.5  192.9
# 1                2           ChinaHotan, China     75.0   50.3  120.0
# 2                3         IndiaBhiwadi, India     85.4  111.4   86.9
# 3                4     IndiaDelhi (NCT), India     99.7  176.8  171.9
# 4                5  PakistanPeshawar, Pakistan    100.0  132.0  212.1
# ...            ...                         ...      ...    ...    ...
# 7318          7319         USACastroville, USA      1.5    1.7    1.4
# 7319          7320              USAWilson, USA      1.1    0.8    0.6
# 7320          7321      USARoanoke Rapids, USA      0.7    0.6    0.8
# 7321          7322    IndonesiaKuta, Indonesia      0.2    0.4    0.3
# 7322          7323           USAArch Cape, USA      0.3    0.8    1.0
#
# [7323 rows x 5 columns]

# %%
df_pandas3.plot(x="Cidade", y=["janeiro", "FEV", "MAR"], kind="bar")
plt.title('Níveis de poluição em janeiro, fevereiro é março 2022 nas quinze cidades que mais poluiram o mundo')
# Out:
# Text(0.5, 1.0, 'Níveis de poluição em janeiro, fevereiro é março 2022 nas quinze cidades que mais poluiram o mundo')

# %%
ax = df_pandas3.plot.pie(y='janeiro', labels=df_pandas3['Cidade'], autopct='%1.1f%%')

ax.legend(bbox_to_anchor=(1.2, 0.5))
plt.title('Níveis de poluição em janeiro de 2022 nas cinco cidades que mais poluiram')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df1.show(500)
# Out:
# +-------------+--------------------+-------+-----+-----+
# |Classificação|              Cidade|janeiro|  FEV|  MAR|
# +-------------+--------------------+-------+-----+-----+
# |            1|PakistanLahore, P...|  133.0|102.5| 85.6|
# |            2|   ChinaHotan, China|   61.7| 91.6|132.7|
# |            3| IndiaBhiwadi, India|  110.6| 98.0|116.2|
# |            4|IndiaDelhi (NCT),...|  141.0|100.9| 91.0|
# |            5|PakistanPeshawar,...|  110.2|103.5| 78.3|
# |            6|IndiaDarbhanga, I...|  127.0| 77.9| 83.1|
# |            7|  IndiaAsopur, India|  110.3| 89.0|104.6|
# |            8| ChadN'Djamena, Chad|  162.3|163.7|245.6|
# |            9|IndiaNew Delhi, I...|  133.7| 95.2| 86.4|
# |           10|   IndiaPatna, India|  128.0| 99.8|105.1|
# |           11|IndiaGhaziabad, I...|  135.5|104.4| 95.5|
# |           12|IndiaDharuhera, I...|  104.3| 74.4| 87.1|
# |           13|   IraqBaghdad, Iraq|   70.6| 53.3| 76.8|
# ...

# %%
# Criando um gráfico de linhas para mostrar a variação dos níveis de poluição em cada cidade durante os meses de outubro, novembro e dezembro
df_pandas4.set_index('Cidade')[['OUTUBRO', 'NOV', 'DEZ']].T.plot(kind='line')

plt.title('Variação dos níveis de poluição em diferentes cidades')
plt.xlabel('Mês')
plt.ylabel('Nível de poluição')
plt.legend(title='Cidade', loc='center left', bbox_to_anchor=(1.0, 0.5), fontsize='large')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
ax = df_pandas3.hist(column='janeiro', bins=10)
plt.titx= y=62.5
In [44]:
le('Níveis de poluição em janeiro de 2022 nas cinco cidades que mais poluiram')
plt.xlabel('Níveis de poluição')
plt.ylabel('Frequência')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">

# %%
import matplotlib.pyplot as plt

# criar gráfico de linhas
df_pandas4.set_index('Cidade')[['OUTUBRO', 'NOV', 'DEZ']].T.plot(kind='line')

# criar lista de rótulos das cidades
labels = ['Cidade A', 'Cidade B', 'Cidade C']

# obter objetos de linha e rótulos de legenda correspondentes
handles, labels = plt.gca().get_legend_handles_labels()
handles = handles[:len(labels)]

# criar nova figura e exibir somente a legenda
fig = plt.figure()
fig.legend(handles, labels, loc='center', title='Cidades', fontsize='large')
fig.set_size_inches(8, 4)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">
# <img src="data:image/png;base64,..." width="799.9999880790713">

# %%
df_pd = df.select("Classificação", "Cidade","janeiro", "FEV", "MAR" )

# %%
media = df_pandas3['janeiro'].mean()

# %%
# %matplotlib notebook
df_plot = df_pandas3[['Cidade', 'janeiro']]
plt.axhline(media, color="black", linestyle="--")


df_plot.plot(kind='barh', x='Cidade', y='janeiro', figsize=(10, 5), legend=False)
plt.xlabel('Poluição (AQI)')
plt.title('Níveis de poluição em janeiro')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="999.999985098839">

# %%
# %matplotlib notebook
df_plot = df_pandas3[['Cidade', 'MAR']]
plt.axhline(media, color="black", linestyle="--")


df_plot.plot(kind='barh', x='Cidade', y='MAR', figsize=(10, 5), legend=False)
plt.xlabel('Poluição (AQI)')
plt.title('Níveis de poluição em março')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="999.999985098839">

# %%
df_pandas3
# Out:
#    Classificação                      Cidade  janeiro    FEV    MAR
# 0              1    PakistanLahore, Pakistan    133.0  102.5   85.6
# 1              2           ChinaHotan, China     61.7   91.6  132.7
# 2              3         IndiaBhiwadi, India    110.6   98.0  116.2
# 3              4     IndiaDelhi (NCT), India    141.0  100.9   91.0
# 4              5  PakistanPeshawar, Pakistan    110.2  103.5   78.3
# 5              6       IndiaDarbhanga, India    127.0   77.9   83.1
# 6              7          IndiaAsopur, India    110.3   89.0  104.6
# 7              8         ChadN'Djamena, Chad    162.3  163.7  245.6
# 8              9       IndiaNew Delhi, India    133.7   95.2   86.4
# 9             10           IndiaPatna, India    128.0   99.8  105.1
# 10            11       IndiaGhaziabad, India    135.5  104.4   95.5
# 11            12       IndiaDharuhera, India    104.3   74.4   87.1
# 12            13           IraqBaghdad, Iraq     70.6   53.3   76.8
# ...

# %%
df_pandas3['É da Índia?'] = df_pandas3['Cidade'].str.contains('India')

# filtrando o DataFrame para incluir apenas cidades da Índia
df_india = df_pandas3[df_pandas3['É da Índia?'] == True]

print(df_india)
# Out:
#    Classificação                     Cidade  janeiro    FEV    MAR  \
# 2              3        IndiaBhiwadi, India    110.6   98.0  116.2
# 3              4    IndiaDelhi (NCT), India    141.0  100.9   91.0
# 5              6      IndiaDarbhanga, India    127.0   77.9   83.1
# 6              7         IndiaAsopur, India    110.3   89.0  104.6
# 8              9      IndiaNew Delhi, India    133.7   95.2   86.4
# 9             10          IndiaPatna, India    128.0   99.8  105.1
# 10            11      IndiaGhaziabad, India    135.5  104.4   95.5
# 11            12      IndiaDharuhera, India    104.3   74.4   87.1
# 13            14         IndiaChapra, India      NaN  114.3  110.3
# 14            15  IndiaMuzaffarnagar, India    120.0   77.5   99.3
#
#     É da Índia?
# 2          True
# 3          True
# 5          True
# 6          True
# 8          True
# 9          True
# 10         True
# 11         True
# 13         True
# 14         True

# %%
df_india
# Out:
#    Classificação                     Cidade  janeiro    FEV    MAR  \
# 2              3        IndiaBhiwadi, India    110.6   98.0  116.2
# 3              4    IndiaDelhi (NCT), India    141.0  100.9   91.0
# 5              6      IndiaDarbhanga, India    127.0   77.9   83.1
# 6              7         IndiaAsopur, India    110.3   89.0  104.6
# 8              9      IndiaNew Delhi, India    133.7   95.2   86.4
# 9             10          IndiaPatna, India    128.0   99.8  105.1
# 10            11      IndiaGhaziabad, India    135.5  104.4   95.5
# 11            12      IndiaDharuhera, India    104.3   74.4   87.1
# 13            14         IndiaChapra, India      NaN  114.3  110.3
# 14            15  IndiaMuzaffarnagar, India    120.0   77.5   99.3
#
#     É da Índia?
# 2          True
# 3          True
# 5          True
# 6          True
# 8          True
# 9          True
# 10         True
# 11         True
# 13         True
# 14         True

# %%
df_pandas['É dos EUA?'] = df_pandas['Cidade'].str.contains('EUA')

# filtrando o DataFrame para incluir apenas cidades da Índia
df_eua = df_pandas[df_pandas['É dos EUA?'] == True]

# %%
df_pandas['É da Índia?'] = df_pandas['Cidade'].str.contains('India')

# filtrando o DataFrame para incluir apenas cidades da Índia
df_india = df_pandas[df_pandas['É da Índia?'] == True]

print(df_india)
# Out:
#      Classificação                   Cidade  janeiro    FEV    MAR  \
# 2                3      IndiaBhiwadi, India    110.6   98.0  116.2
# 3                4  IndiaDelhi (NCT), India    141.0  100.9   91.0
# 5                6    IndiaDarbhanga, India    127.0   77.9   83.1
# 6                7       IndiaAsopur, India    110.3   89.0  104.6
# 8                9    IndiaNew Delhi, India    133.7   95.2   86.4
# ...            ...                      ...      ...    ...    ...
# 7110          7111   IndiaKattupalli, India      4.1    3.6    3.0
# 7132          7133        IndiaAladu, India      2.0    2.0    3.5
# 7293          7294       IndiaDigboi, India      0.4    0.3    1.3
# 7310          7311     USAIndian Creek, USA      1.0    1.0    1.1
# 7314          7315   IndiaTarakeswar, India      2.3    2.0    1.9
#
#       É dos EUA?  É da Índia?
# 2          False         True
# 3          False         True
# 5          False         True
# 6          False         True
# ...

# %%
len(df_india)
# Out:
# 207

# %%
df_abreviado.show(50)
# Out:
# +-------------+--------------------+
# |Classificação|              Cidade|
# +-------------+--------------------+
# |            1|PakistanLahore, P...|
# |            2|   ChinaHotan, China|
# |            3| IndiaBhiwadi, India|
# |            4|IndiaDelhi (NCT),...|
# |            5|PakistanPeshawar,...|
# |            6|IndiaDarbhanga, I...|
# |            7|  IndiaAsopur, India|
# |            8| ChadN'Djamena, Chad|
# |            9|IndiaNew Delhi, I...|
# |           10|   IndiaPatna, India|
# |           11|IndiaGhaziabad, I...|
# |           12|IndiaDharuhera, I...|
# |           13|   IraqBaghdad, Iraq|
# |           14|  IndiaChapra, India|
# |           15|IndiaMuzaffarnaga...|
# |           16|PakistanFaisalaba...|
# |           17|IndiaGreater Noid...|
# |           18|IndiaBahadurgarh,...|
# |           19|IndiaFaridabad, I...|
# |           20|IndiaMuzaffarpur,...|
# |           21|   IndiaNoida, India|
# |           22|    IndiaJind, India|
# ...

# %%
df_abreviado = df.select("Classificação", "Cidade")

# %%
df_agrupado
# Out:
#                                     janeiro   FEV   MAR  É da Índia?  \
# Cidade
# AfghanistanKabul, Afghanistan          54.9  28.5   8.7            0
# AlbaniaTirana, Albania                 20.1  18.6  18.1            0
# AlgeriaAlgiers, Algeria                22.6  17.5  22.5            0
# AndorraOrdino, Andorra                  2.9   4.0   5.9            0
# AngolaLuanda, Angola                    9.5  12.1  11.1            0
# ...                                     ...   ...   ...          ...
# VietnamThanh Pho Lang Son, Vietnam     43.3  28.2  16.6            0
# VietnamThu Duc, Vietnam                31.6  20.6  24.3            0
# VietnamTra Vinh, Vietnam                6.3   6.6   5.7            0
# VietnamTrang Bang, Vietnam              9.3  15.7  17.5            0
# ZambiaLusaka, Zambia                    7.7  10.2   8.6            0
#
#                                     É dos EUA?  É da China?
# Cidade
# AfghanistanKabul, Afghanistan                0            0
# ...

# %%
df_agrupado.plot(kind='pie', y='janeiro', legend=False)
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">
# <Axes: ylabel='janeiro'>

# %%
contagem2 = df_pandas["É dos EUA?"].value_counts()

# %%
contagem = df_pandas["É da Índia?"].value_counts()

df_pandas['É da Índia?'] = df_pandas['Cidade'].str.contains('India')

# filtrando as cidades da Índia
df_india = df_pandas[df_pandas['É da Índia?'] == True]

fig, ax = plt.subplots()
ax.pie(contagem.values, labels=contagem.index, autopct="%1.1f%%")
ax.set_title("cidades da india que mais poluem")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">

# %%
df_pandas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7323 entries, 0 to 7322
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Classificação  7323 non-null   object
#  1   Cidade         7323 non-null   object
#  2   janeiro        7099 non-null   float64
#  3   FEV            7153 non-null   float64
#  4   MAR            7240 non-null   float64
#  5   É dos EUA?     7323 non-null   bool
#  6   É da Índia?    7323 non-null   bool
# dtypes: bool(2), float64(3), object(2)
# memory usage: 300.5+ KB

# %%
# Plotar as informações em um gráfico de barras
fig, ax = plt.subplots()
ax.pie(contagem2.values, labels=contagem.index, autopct="%1.1f%%")
ax.set_xlabel("cidades dos EUA")

ax.set_title("Contagem de cidades nos EUA")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">

# %%
df_pandas['É da China?'] = df_pandas['Cidade'].str.contains('China')

# filtrando o DataFrame para incluir apenas cidades da Índia
df_china = df_pandas[df_pandas['É da China?'] == True]

# %%
# Plotar as informações em um gráfico de barras
fig, ax = plt.subplots()
ax.pie(contagem3.values, labels=contagem.index, autopct="%1.1f%%")
ax.set_xlabel("cidades da China")

ax.set_title("Contagem de cidades na China")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
len(df_china)
# Out:
# 525
